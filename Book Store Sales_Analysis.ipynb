# %% [markdown]
# # Book Store Data Analysis

# %%
# import python libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Sales Analysis.csv', encoding = 'unicode_escape' )

# %%
df.shape
# Out:
# (25000, 13)

# %% [markdown]
# here we can the shape of our file which shows 25000 rows and 13 columns

# %%
df.head(7)
# Out:
#     User_ID         Cust_Name  Product_ID  Gender Age_Group   Age  \
# 0  100000.0       Amit Sharma      1591.0  Female     26-35  54.0
# 1  100001.0       Rahul Singh      2426.0   Other     36-45  38.0
# 2  100002.0  Deepak Choudhary      3959.0    Male     46-60  55.0
# 3  100003.0       Priya Verma      1937.0   Other     46-60  69.0
# 4  100004.0      Sanjay Mehta      4256.0  Female     46-60  68.0
# 5  100005.0  Deepak Choudhary      2268.0  Female     18-25  22.0
# 6  100006.0       Priya Verma         NaN    Male     46-60  55.0
#
#   Marital_Status      State     Zone Occupation                  Books  \
# 0       Divorced         UP    South        NaN        The White Tiger
# 1        Married        NaN    North     Doctor              Gitanjali
# 2        Married    Gujarat     East     Doctor  Midnightâs Children
# 3       Divorced  Karnataka     East     Artist        The White Tiger
# 4        Married  Karnataka  Central   Business        The White Tiger
# ...

# %% [markdown]
# by this command we can see top persons data, If you wanted to more data then we have to specify a rows up to,
# we also have tail() command like that but tail command shows last 5 rows.

# %%
# it is good to know columns and their correspoanding data types and also which columns have null dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User_ID         23750 non-null  float64
#  1   Cust_Name       25000 non-null  object
#  2   Product_ID      23750 non-null  float64
#  3   Gender          23750 non-null  object
#  4   Age_Group       23750 non-null  object
#  5   Age             23750 non-null  float64
#  6   Marital_Status  23750 non-null  object
#  7   State           23750 non-null  object
#  8   Zone            23750 non-null  object
#  9   Occupation      23750 non-null  object
#  10  Books           25000 non-null  object
#  11  Orders          23750 non-null  float64
#  12  Amount          25000 non-null  float64
# dtypes: float64(5), object(8)
# memory usage: 2.5+ MB

# %%
#drop unrelated/blank columns
#its alredy droped thats why its showing a error slide
df.drop([], axis=1, inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID           1250
# Cust_Name            0
# Product_ID        1250
# Gender            1250
# Age_Group         1250
# Age               1250
# Marital_Status    1250
# State             1250
# Zone              1250
# Occupation        1250
# Books                0
# Orders            1250
# Amount               0
# dtype: int64

# %%
df['Amount'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# If we wanted to know the datatype of any column we run above command

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_Name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Books', 'Orders',
#        'Amount'],
#       dtype='object')

# %% [markdown]
# Sometimes we has to ackknowledge all columns so we can run above column

# %%
df.rename(columns= {'Gender':'Sex'})
# Out:
#         User_ID         Cust_Name  Product_ID     Sex Age_Group   Age  \
# 0      100000.0       Amit Sharma      1591.0  Female     26-35  54.0
# 1      100001.0       Rahul Singh      2426.0   Other     36-45  38.0
# 2      100002.0  Deepak Choudhary      3959.0    Male     46-60  55.0
# 3      100003.0       Priya Verma      1937.0   Other     46-60  69.0
# 4      100004.0      Sanjay Mehta      4256.0  Female     46-60  68.0
# ...         ...               ...         ...     ...       ...   ...
# 24995  124995.0       Arjun Reddy      3877.0  Female       60+  26.0
# 24996  124996.0       Vikram Iyer      4729.0     NaN     46-60  39.0
# 24997  124997.0       Vikram Iyer      4103.0  Female       60+  59.0
# 24998  124998.0      Kavita Joshi      2308.0   Other     18-25  31.0
# 24999  124999.0       Priya Verma      2287.0  Female     36-45  33.0
#
#       Marital_Status        State     Zone Occupation  \
# 0           Divorced           UP    South        NaN
# ...

# %% [markdown]
# Imagine we wanted to change a column name so can changed it like above column (Note: its done on only temporary basis)

# %%
df.describe()
# Out:
#              User_ID    Product_ID           Age        Orders        Amount
# count   23750.000000  23750.000000  23750.000000  23750.000000  25000.000000
# mean   112513.659326   3003.521137     43.749811      5.007453   4854.530486
# std      7221.843383   1159.989366     15.034937      2.598886   2727.479204
# min    100000.000000   1000.000000     18.000000      1.000000    255.080000
# 25%    106250.250000   1998.000000     31.000000      3.000000   2590.530000
# 50%    112529.500000   3005.000000     44.000000      5.000000   6049.980000
# 75%    118767.750000   4004.000000     57.000000      7.000000   7435.000000
# max    124999.000000   4999.000000     69.000000      9.000000   8854.810000

# %% [markdown]
# This command returns description of the data in this dataframe. we also use it for specific columns

# %%
df[['User_ID', 'Orders', 'Amount']].describe()
# Out:
#              User_ID        Orders        Amount
# count   23750.000000  23750.000000  25000.000000
# mean   112513.659326      5.007453   4854.530486
# std      7221.843383      2.598886   2727.479204
# min    100000.000000      1.000000    255.080000
# 25%    106250.250000      3.000000   2590.530000
# 50%    112529.500000      5.000000   6049.980000
# 75%    118767.750000      7.000000   7435.000000
# max    124999.000000      9.000000   8854.810000

# %% [markdown]
# ### EDA : Exploitary Data Analysis
# #### By using EDA we analyze the datasets to summarized their main characteristics, often using Visual methods

# %% [markdown]
# #### Gender

# %%
ax = sns.countplot(x = 'Gender',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Using this we can analyze readers gender to easily engaged with readers.

# %% [markdown]
# ### State

# %% [markdown]
# In below chart we can analyze our books orders on State basis which order in top 7.

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(7)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# In below chart we can analyze our amount (revenue) of orders on State basis which order in top 7.And can also make a decision where we need to do efforts for getting more revenue

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(7)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# on below countplot we analyze marital status of readers for getting some personal information about a readers.

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# on below barplot we analyze marital status of readers on gender basis for getting some personal information about a readers.

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# below chart shows us a occupation of a readers and by this we can conclude our data if get some genre's of books for reader according to occupation.

# %% [markdown]
# ## Occupation

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax = sns.countplot(data = df, x = 'Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# By this below barplot we can analyze the our revenue on a occupation basis.

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# By this below countplot we can analyze the data about books status that how may books are we have on which topic so they easily gather with reader whether they have it or not

# %% [markdown]
# ### Books

# %%
sns.set(rc={'figure.figsize':(20,5),'font.family': 'DejaVu Sans'})
ax = sns.countplot(data = df, x = 'Books')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128 (\x80) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 153 (\x99) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128 (\x80) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 153 (\x99) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# By this below barplot we can analyze the data amount of a books so we can easily understand which books are most selling.

# %%
sales_state = df.groupby(['Books'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Books',y= 'Amount')
# Out:
# <Axes: xlabel='Books', ylabel='Amount'>

# %% [markdown]
# Below chart configure the orders with Product_ID so we easily gathered the data about books

# %%
fig1, ax1 = plt.subplots(figsize=(10,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# Below chart is line chart which shows us orders with reader name.

# %% [markdown]
# ### Line Chart

# %%
filtered_data = df.groupby('Cust_Name', as_index=False) ['Orders'].sum().dropna().head(5)

plt.figure(figsize=(10, 6))
plt.plot(filtered_data['Orders'], filtered_data['Cust_Name'], marker='o')

# Adding labels and title
plt.xlabel('Orders')
plt.ylabel('Cust_Name')
plt.title('First 5 Data Points')
plt.grid(True)
plt.show()

# %% [markdown]
# Below Pie Chart shows the percent of orders in top states.

# %% [markdown]
# # Pie Chart

# %%
# Grouping by 'State' and summing up the number of orders
state_order_data = df.groupby('State')['Orders'].sum().dropna().head(5)

# Plotting the pie chart for orders by state
plt.figure(figsize=(8, 8))
plt.pie(state_order_data, labels=state_order_data.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Distribution of Orders by State')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %% [markdown]
# below is a barplot which shows us a orders with along with the customers name.

# %% [markdown]
# ### Barplot

# %%
filtered_data = df.groupby('Cust_Name', as_index=False) ['Orders'].sum().dropna().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(filtered_data, x="Orders", y="Cust_Name" , hue="Cust_Name", palette="coolwarm", legend=False)
plt.xlabel('orders')
plt.ylabel('Customer Names')
plt.title('Barplot based on orders and Customers')
plt.show()

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# ##### Python provides a comprehensive toolset for performing book store sales analysis, from cleaning and merging data to performing complex visualizations and predictive analytics. Insights drawn from this analysis can help bookstores optimize inventory, target customer segments, and forecast future sales trends.

# %% [markdown]
# ##### Key Insights:
# ##### 1. Top selling categories
# #####    . Best selling books
# ##### 2. Customer purchased behaviour
# #####    . Repeated Customer
# ##### 3. Marketing effectiveness
# #####    . upscaling opportunities

# %% [markdown]
# ##### Summary:
# #####   1) Data preprocessing for cleaning and formatting a data.
# #####   2) EDA- Identify the key trends and analyze the customer demographics to understand which group acn understand more.
# #####   3) predictive analysis - Sales forcasting.
# #####   4) Predict demands of popular books to ensure stack.
